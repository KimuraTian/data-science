# %% [markdown]
# ## Gathering Electricity Prices in USA

# %% [markdown]
# Load libraries

# %%
library(jsonlite)
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
options(repr.matrix.max.rows=20)

# %% [markdown]
# Read the list of United States Zip Codes
# - The data file is downloaded from <a href="https://www.aggdata.com/download_sample.php?file=us_postal_codes.csv">AggData</a>

# %%
cities.usa = read_csv("data/us_postal_codes.csv")
head(cities.usa)
# Out:
# Parsed with column specification:
# cols(
#   `Zip Code` = col_integer(),
#   `Place Name` = col_character(),
#   State = col_character(),
#   `State Abbreviation` = col_character(),
#   County = col_character(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#   Zip Code Place Name State         State Abbreviation County    Latitude
# 1  501     Holtsville New York      NY                 Suffolk   40.8154
# 2  544     Holtsville New York      NY                 Suffolk   40.8154
# 3 1001     Agawam     Massachusetts MA                 Hampden   42.0702
# 4 1002     Amherst    Massachusetts MA                 Hampshire 42.3671
# 5 1003     Amherst    Massachusetts MA                 Hampshire 42.3919
# 6 1004     Amherst    Massachusetts MA                 Hampshire 42.3845
#   Longitude
# 1 -73.0451
# 2 -73.0451
# 3 -72.6227
# 4 -72.4646
# 5 -72.5248
# 6 -72.5132

# %% [markdown]
# We care about Idaho and Washington

# %%
cities.selected = cities.usa %>%
    filter(`State Abbreviation` == 'OR') %>%
    select(`Place Name`, State) %>%
    distinct()
cities.selected
# Out:
#     Place Name    State
# 1   Antelope      Oregon
# 2   Aurora        Oregon
# 3   Beaverton     Oregon
# 4   Beavercreek   Oregon
# 5   Boring        Oregon
# 6   Bridal Veil   Oregon
# 7   Brightwood    Oregon
# 8   Canby         Oregon
# 9   Cascade Locks Oregon
# 10  Clackamas     Oregon
# ⋮   ⋮             ⋮
# 364 Huntington    Oregon
# 365 Ironside      Oregon
# 366 Jamieson      Oregon
# 367 Jordan Valley Oregon
# 368 Juntura       Oregon
# 369 Nyssa         Oregon
# 370 Ontario       Oregon
# 371 Riverside     Oregon
# 372 Vale          Oregon
# 373 Westfall      Oregon

# %% [markdown]
# How many cities do we need to retrieve?

# %%
cities.selected %>%
    nrow()
# Out:
# [1] 373

# %% [markdown]
# Create a place list

# %%
places = cities.selected %>%
    mutate(`Place Name` = gsub(" ", "%20", `Place Name`)) %>%
    .$`Place Name`

# %%
length(places)
# Out:
# [1] 373

# %% [markdown]
# A function to retrieve electricity prices.
# - This function uses <a href = "https://developer.nrel.gov/docs/electricity/utility-rates-v3/#request-url">NREL API</a>.
# - Link Example: "https&#58;//developer.nrel.gov/api/utility_rates/v3.json?api_key=yourKey&address=boise&lat=20&lon=20"

# %%
get_electricity_prices = function(placesList, maxCallPerCity=2, callInterval=10) {
    
    totalCityNum = length(placesList)
    currentCityNum = 1
    
    for (city in placesList) {
        linkAddress = sprintf("https://developer.nrel.gov/api/utility_rates/v3.json?api_key=qtSpExfVW4iaoxskxPOXVrUEiZQcj7RFaVayvJ3H&address=%s", city)
        message("reading data for city: ", city, ". remaining cities: ", totalCityNum - currentCityNum)
                # record times of calling the current currency
        
        callNum = 1
        assign("currentData", NULL, envir=.GlobalEnv)
        hadError = TRUE
        while (hadError == TRUE && callNum <= maxCallPerCity) {
            hadError = tryCatch({
                jsonList = fromJSON(linkAddress)
                assign("currentData", 
                           as.data.frame(rbind(unlist(jsonList))), 
                           envir=.GlobalEnv)
            FALSE
        }, warning = function(warn) {
                assign("currentData", NULL, envir=.GlobalEnv)
#                 message('errors')
                TRUE
            }, error = function(err) {
                assign("currentData", NULL, envir=.GlobalEnv)
#                 message('errors')
                TRUE
        })
            callNum = callNum + 1
#             message('current call number', callNum)
            Sys.sleep(callInterval)
        }
        
        if (!is.null(currentData)) {
            if (currentCityNum == 1) {
                write_csv(currentData, "data/electricity_price_OR_re.csv")
            } else {
                write_csv(currentData, "data/electricity_price_OR_re.csv", append = TRUE)
            }
            message(city, " data is successfully written to electricity_price_WY.csv")
        } else {
           message(city, " data retrieving failed")
        }
        
        currentCityNum = currentCityNum + 1
            
    }
}

# %% [markdown]
# ### Skip next line if the data has already been retrieved.

# %%
get_electricity_prices(places)
# Out:
# reading data for city: Antelope. remaining cities: 372
# Antelope data is successfully written to electricity_price_WY.csv
# reading data for city: Aurora. remaining cities: 371
# Aurora data is successfully written to electricity_price_WY.csv
# reading data for city: Beaverton. remaining cities: 370
# Beaverton data is successfully written to electricity_price_WY.csv
# reading data for city: Beavercreek. remaining cities: 369
# Beavercreek data is successfully written to electricity_price_WY.csv
# reading data for city: Boring. remaining cities: 368
# Boring data is successfully written to electricity_price_WY.csv
# reading data for city: Bridal%20Veil. remaining cities: 367
# Bridal%20Veil data is successfully written to electricity_price_WY.csv
# reading data for city: Brightwood. remaining cities: 366
# Brightwood data is successfully written to electricity_price_WY.csv
# reading data for city: Canby. remaining cities: 365
# Canby data is successfully written to electricity_price_WY.csv
# reading data for city: Cascade%20Locks. remaining cities: 364
# Cascade%20Locks data is successfully written to electricity_price_WY.csv
# reading data for city: Clackamas. remaining cities: 363
# Clackamas data is successfully written to electricity_price_WY.csv
# reading data for city: Clatskanie. remaining cities: 362
# Clatskanie data is successfully written to electricity_price_WY.csv
# reading data for city: Colton. remaining cities: 361
# Colton data is successfully written to electricity_price_WY.csv
# reading data for city: Columbia%20City. remaining cities: 360
# Columbia%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Corbett. remaining cities: 359
# Corbett data is successfully written to electricity_price_WY.csv
# reading data for city: Donald. remaining cities: 358
# Donald data is successfully written to electricity_price_WY.csv
# reading data for city: Dufur. remaining cities: 357
# Dufur data is successfully written to electricity_price_WY.csv
# reading data for city: Eagle%20Creek. remaining cities: 356
# Eagle%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Estacada. remaining cities: 355
# Estacada data is successfully written to electricity_price_WY.csv
# reading data for city: Fairview. remaining cities: 354
# Fairview data is successfully written to electricity_price_WY.csv
# reading data for city: Gervais. remaining cities: 353
# Gervais data is successfully written to electricity_price_WY.csv
# reading data for city: Gladstone. remaining cities: 352
# Gladstone data is successfully written to electricity_price_WY.csv
# reading data for city: Government%20Camp. remaining cities: 351
# Government%20Camp data is successfully written to electricity_price_WY.csv
# reading data for city: Grass%20Valley. remaining cities: 350
# Grass%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Gresham. remaining cities: 349
# Gresham data is successfully written to electricity_price_WY.csv
# reading data for city: Hood%20River. remaining cities: 348
# Hood%20River data is successfully written to electricity_price_WY.csv
# reading data for city: Hubbard. remaining cities: 347
# Hubbard data is successfully written to electricity_price_WY.csv
# reading data for city: Kent. remaining cities: 346
# Kent data is successfully written to electricity_price_WY.csv
# reading data for city: Lake%20Oswego. remaining cities: 345
# Lake%20Oswego data is successfully written to electricity_price_WY.csv
# reading data for city: Marylhurst. remaining cities: 344
# Marylhurst data is successfully written to electricity_price_WY.csv
# reading data for city: Maupin. remaining cities: 343
# Maupin data is successfully written to electricity_price_WY.csv
# reading data for city: Molalla. remaining cities: 342
# Molalla data is successfully written to electricity_price_WY.csv
# reading data for city: Moro. remaining cities: 341
# Moro data is successfully written to electricity_price_WY.csv
# reading data for city: Mosier. remaining cities: 340
# Mosier data is successfully written to electricity_price_WY.csv
# reading data for city: Mount%20Hood%20Parkdale. remaining cities: 339
# Mount%20Hood%20Parkdale data is successfully written to electricity_price_WY.csv
# reading data for city: Mulino. remaining cities: 338
# Mulino data is successfully written to electricity_price_WY.csv
# reading data for city: Odell. remaining cities: 337
# Odell data is successfully written to electricity_price_WY.csv
# reading data for city: Oregon%20City. remaining cities: 336
# Oregon%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Rainier. remaining cities: 335
# Rainier data is successfully written to electricity_price_WY.csv
# reading data for city: Rhododendron. remaining cities: 334
# Rhododendron data is successfully written to electricity_price_WY.csv
# reading data for city: Rufus. remaining cities: 333
# Rufus data is successfully written to electricity_price_WY.csv
# reading data for city: Saint%20Helens. remaining cities: 332
# Saint%20Helens data is successfully written to electricity_price_WY.csv
# reading data for city: Warren. remaining cities: 331
# Warren data is successfully written to electricity_price_WY.csv
# reading data for city: Deer%20Island. remaining cities: 330
# Deer%20Island data is successfully written to electricity_price_WY.csv
# reading data for city: Sandy. remaining cities: 329
# Sandy data is successfully written to electricity_price_WY.csv
# reading data for city: Scappoose. remaining cities: 328
# Scappoose data is successfully written to electricity_price_WY.csv
# reading data for city: Shaniko. remaining cities: 327
# Shaniko data is successfully written to electricity_price_WY.csv
# reading data for city: The%20Dalles. remaining cities: 326
# The%20Dalles data is successfully written to electricity_price_WY.csv
# reading data for city: Troutdale. remaining cities: 325
# Troutdale data is successfully written to electricity_price_WY.csv
# reading data for city: Tualatin. remaining cities: 324
# Tualatin data is successfully written to electricity_price_WY.csv
# reading data for city: Tygh%20Valley. remaining cities: 323
# Tygh%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Vernonia. remaining cities: 322
# Vernonia data is successfully written to electricity_price_WY.csv
# reading data for city: Wasco. remaining cities: 321
# Wasco data is successfully written to electricity_price_WY.csv
# reading data for city: Welches. remaining cities: 320
# Welches data is successfully written to electricity_price_WY.csv
# reading data for city: West%20Linn. remaining cities: 319
# West%20Linn data is successfully written to electricity_price_WY.csv
# reading data for city: Wilsonville. remaining cities: 318
# Wilsonville data is successfully written to electricity_price_WY.csv
# reading data for city: Woodburn. remaining cities: 317
# Woodburn data is successfully written to electricity_price_WY.csv
# reading data for city: Happy%20Valley. remaining cities: 316
# Happy%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Damascus. remaining cities: 315
# Damascus data is successfully written to electricity_price_WY.csv
# reading data for city: Amity. remaining cities: 314
# Amity data is successfully written to electricity_price_WY.csv
# reading data for city: Arch%20Cape. remaining cities: 313
# Arch%20Cape data is successfully written to electricity_price_WY.csv
# reading data for city: Astoria. remaining cities: 312
# Astoria data is successfully written to electricity_price_WY.csv
# reading data for city: Banks. remaining cities: 311
# Banks data is successfully written to electricity_price_WY.csv
# reading data for city: Bay%20City. remaining cities: 310
# Bay%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Beaver. remaining cities: 309
# Beaver data is successfully written to electricity_price_WY.csv
# reading data for city: Buxton. remaining cities: 308
# Buxton data is successfully written to electricity_price_WY.csv
# reading data for city: Cannon%20Beach. remaining cities: 307
# Cannon%20Beach data is successfully written to electricity_price_WY.csv
# reading data for city: Carlton. remaining cities: 306
# Carlton data is successfully written to electricity_price_WY.csv
# reading data for city: Cloverdale. remaining cities: 305
# Cloverdale data is successfully written to electricity_price_WY.csv
# reading data for city: Cornelius. remaining cities: 304
# Cornelius data is successfully written to electricity_price_WY.csv
# reading data for city: Dayton. remaining cities: 303
# Dayton data is successfully written to electricity_price_WY.csv
# reading data for city: Dundee. remaining cities: 302
# Dundee data is successfully written to electricity_price_WY.csv
# reading data for city: Forest%20Grove. remaining cities: 301
# Forest%20Grove data is successfully written to electricity_price_WY.csv
# reading data for city: Gales%20Creek. remaining cities: 300
# Gales%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Garibaldi. remaining cities: 299
# Garibaldi data is successfully written to electricity_price_WY.csv
# reading data for city: Gaston. remaining cities: 298
# Gaston data is successfully written to electricity_price_WY.csv
# reading data for city: Hammond. remaining cities: 297
# Hammond data is successfully written to electricity_price_WY.csv
# reading data for city: Hebo. remaining cities: 296
# Hebo data is successfully written to electricity_price_WY.csv
# reading data for city: Hillsboro. remaining cities: 295
# Hillsboro data is successfully written to electricity_price_WY.csv
# reading data for city: Manning. remaining cities: 294
# Manning data is successfully written to electricity_price_WY.csv
# reading data for city: Lafayette. remaining cities: 293
# Lafayette data is successfully written to electricity_price_WY.csv
# reading data for city: Mcminnville. remaining cities: 292
# Mcminnville data is successfully written to electricity_price_WY.csv
# reading data for city: Manzanita. remaining cities: 291
# Manzanita data is successfully written to electricity_price_WY.csv
# reading data for city: Nehalem. remaining cities: 290
# Nehalem data is successfully written to electricity_price_WY.csv
# reading data for city: Newberg. remaining cities: 289
# Newberg data is successfully written to electricity_price_WY.csv
# reading data for city: North%20Plains. remaining cities: 288
# North%20Plains data is successfully written to electricity_price_WY.csv
# reading data for city: Oceanside. remaining cities: 287
# Oceanside data is successfully written to electricity_price_WY.csv
# reading data for city: Pacific%20City. remaining cities: 286
# Pacific%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Rockaway%20Beach. remaining cities: 285
# Rockaway%20Beach data is successfully written to electricity_price_WY.csv
# reading data for city: Saint%20Paul. remaining cities: 284
# Saint%20Paul data is successfully written to electricity_price_WY.csv
# reading data for city: Seaside. remaining cities: 283
# Seaside data is successfully written to electricity_price_WY.csv
# reading data for city: Sherwood. remaining cities: 282
# Sherwood data is successfully written to electricity_price_WY.csv
# reading data for city: Tillamook. remaining cities: 281
# Tillamook data is successfully written to electricity_price_WY.csv
# reading data for city: Netarts. remaining cities: 280
# Netarts data is successfully written to electricity_price_WY.csv
# reading data for city: Timber. remaining cities: 279
# Timber data is successfully written to electricity_price_WY.csv
# reading data for city: Tolovana%20Park. remaining cities: 278
# Tolovana%20Park data is successfully written to electricity_price_WY.csv
# reading data for city: Warrenton. remaining cities: 277
# Warrenton data is successfully written to electricity_price_WY.csv
# reading data for city: Wheeler. remaining cities: 276
# Wheeler data is successfully written to electricity_price_WY.csv
# reading data for city: Yamhill. remaining cities: 275
# Yamhill data is successfully written to electricity_price_WY.csv
# reading data for city: Neskowin. remaining cities: 274
# Neskowin data is successfully written to electricity_price_WY.csv
# reading data for city: Portland. remaining cities: 273
# Portland data is successfully written to electricity_price_WY.csv
# reading data for city: Salem. remaining cities: 272
# Salem data is successfully written to electricity_price_WY.csv
# reading data for city: Keizer. remaining cities: 271
# Keizer data is successfully written to electricity_price_WY.csv
# reading data for city: Albany. remaining cities: 270
# Albany data is successfully written to electricity_price_WY.csv
# reading data for city: Alsea. remaining cities: 269
# Alsea data is successfully written to electricity_price_WY.csv
# reading data for city: Aumsville. remaining cities: 268
# Aumsville data is successfully written to electricity_price_WY.csv
# reading data for city: Blodgett. remaining cities: 267
# Blodgett data is successfully written to electricity_price_WY.csv
# reading data for city: Brownsville. remaining cities: 266
# Brownsville data is successfully written to electricity_price_WY.csv
# reading data for city: Cascadia. remaining cities: 265
# Cascadia data is successfully written to electricity_price_WY.csv
# reading data for city: Corvallis. remaining cities: 264
# Corvallis data is successfully written to electricity_price_WY.csv
# reading data for city: Crabtree. remaining cities: 263
# Crabtree data is successfully written to electricity_price_WY.csv
# reading data for city: Crawfordsville. remaining cities: 262
# Crawfordsville data is successfully written to electricity_price_WY.csv
# reading data for city: Dallas. remaining cities: 261
# Dallas data is successfully written to electricity_price_WY.csv
# reading data for city: Depoe%20Bay. remaining cities: 260
# Depoe%20Bay data is successfully written to electricity_price_WY.csv
# reading data for city: Detroit. remaining cities: 259
# Detroit data is successfully written to electricity_price_WY.csv
# reading data for city: Eddyville. remaining cities: 258
# Eddyville data is successfully written to electricity_price_WY.csv
# reading data for city: Falls%20City. remaining cities: 257
# Falls%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Foster. remaining cities: 256
# Foster data is successfully written to electricity_price_WY.csv
# reading data for city: Gates. remaining cities: 255
# Gates data is successfully written to electricity_price_WY.csv
# reading data for city: Grand%20Ronde. remaining cities: 254
# Grand%20Ronde data is successfully written to electricity_price_WY.csv
# reading data for city: Halsey. remaining cities: 253
# Halsey data is successfully written to electricity_price_WY.csv
# reading data for city: Idanha. remaining cities: 252
# Idanha data is successfully written to electricity_price_WY.csv
# reading data for city: Independence. remaining cities: 251
# Independence data is successfully written to electricity_price_WY.csv
# reading data for city: Jefferson. remaining cities: 250
# Jefferson data is successfully written to electricity_price_WY.csv
# reading data for city: Lebanon. remaining cities: 249
# Lebanon data is successfully written to electricity_price_WY.csv
# reading data for city: Logsden. remaining cities: 248
# Logsden data is successfully written to electricity_price_WY.csv
# reading data for city: Lyons. remaining cities: 247
# Lyons data is successfully written to electricity_price_WY.csv
# reading data for city: Mill%20City. remaining cities: 246
# Mill%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Monmouth. remaining cities: 245
# Monmouth data is successfully written to electricity_price_WY.csv
# reading data for city: Mount%20Angel. remaining cities: 244
# Mount%20Angel data is successfully written to electricity_price_WY.csv
# reading data for city: Neotsu. remaining cities: 243
# Neotsu data is successfully written to electricity_price_WY.csv
# reading data for city: Newport. remaining cities: 242
# Newport data is successfully written to electricity_price_WY.csv
# reading data for city: South%20Beach. remaining cities: 241
# South%20Beach data is successfully written to electricity_price_WY.csv
# reading data for city: Lincoln%20City. remaining cities: 240
# Lincoln%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Otis. remaining cities: 239
# Otis data is successfully written to electricity_price_WY.csv
# reading data for city: Otter%20Rock. remaining cities: 238
# Otter%20Rock data is successfully written to electricity_price_WY.csv
# reading data for city: Philomath. remaining cities: 237
# Philomath data is successfully written to electricity_price_WY.csv
# reading data for city: Rickreall. remaining cities: 236
# Rickreall data is successfully written to electricity_price_WY.csv
# reading data for city: Saint%20Benedict. remaining cities: 235
# Saint%20Benedict data is successfully written to electricity_price_WY.csv
# reading data for city: Scio. remaining cities: 234
# Scio data is successfully written to electricity_price_WY.csv
# reading data for city: Scotts%20Mills. remaining cities: 233
# Scotts%20Mills data is successfully written to electricity_price_WY.csv
# reading data for city: Seal%20Rock. remaining cities: 232
# Seal%20Rock data is successfully written to electricity_price_WY.csv
# reading data for city: Shedd. remaining cities: 231
# Shedd data is successfully written to electricity_price_WY.csv
# reading data for city: Sheridan. remaining cities: 230
# Sheridan data is successfully written to electricity_price_WY.csv
# reading data for city: Siletz. remaining cities: 229
# Siletz data is successfully written to electricity_price_WY.csv
# reading data for city: Silverton. remaining cities: 228
# Silverton data is successfully written to electricity_price_WY.csv
# reading data for city: Stayton. remaining cities: 227
# Stayton data is successfully written to electricity_price_WY.csv
# reading data for city: Mehama. remaining cities: 226
# Mehama data is successfully written to electricity_price_WY.csv
# reading data for city: Sublimity. remaining cities: 225
# Sublimity data is successfully written to electricity_price_WY.csv
# reading data for city: Sweet%20Home. remaining cities: 224
# Sweet%20Home data is successfully written to electricity_price_WY.csv
# reading data for city: Gleneden%20Beach. remaining cities: 223
# Gleneden%20Beach data is successfully written to electricity_price_WY.csv
# reading data for city: Tangent. remaining cities: 222
# Tangent data is successfully written to electricity_price_WY.csv
# reading data for city: Tidewater. remaining cities: 221
# Tidewater data is successfully written to electricity_price_WY.csv
# reading data for city: Toledo. remaining cities: 220
# Toledo data is successfully written to electricity_price_WY.csv
# reading data for city: Turner. remaining cities: 219
# Turner data is successfully written to electricity_price_WY.csv
# reading data for city: Waldport. remaining cities: 218
# Waldport data is successfully written to electricity_price_WY.csv
# reading data for city: Willamina. remaining cities: 217
# Willamina data is successfully written to electricity_price_WY.csv
# reading data for city: Eugene. remaining cities: 216
# Eugene data is successfully written to electricity_price_WY.csv
# reading data for city: Agness. remaining cities: 215
# Agness data is successfully written to electricity_price_WY.csv
# reading data for city: Allegany. remaining cities: 214
# Allegany data is successfully written to electricity_price_WY.csv
# reading data for city: Alvadore. remaining cities: 213
# Alvadore data is successfully written to electricity_price_WY.csv
# reading data for city: Azalea. remaining cities: 212
# Azalea data is successfully written to electricity_price_WY.csv
# reading data for city: Bandon. remaining cities: 211
# Bandon data is successfully written to electricity_price_WY.csv
# reading data for city: Blachly. remaining cities: 210
# Blachly data is successfully written to electricity_price_WY.csv
# reading data for city: Blue%20River. remaining cities: 209
# Blue%20River data is successfully written to electricity_price_WY.csv
# reading data for city: Broadbent. remaining cities: 208
# Broadbent data is successfully written to electricity_price_WY.csv
# reading data for city: Brookings. remaining cities: 207
# Brookings data is successfully written to electricity_price_WY.csv
# reading data for city: Camas%20Valley. remaining cities: 206
# Camas%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Canyonville. remaining cities: 205
# Canyonville data is successfully written to electricity_price_WY.csv
# reading data for city: Cheshire. remaining cities: 204
# Cheshire data is successfully written to electricity_price_WY.csv
# reading data for city: Coos%20Bay. remaining cities: 203
# Coos%20Bay data is successfully written to electricity_price_WY.csv
# reading data for city: Coquille. remaining cities: 202
# Coquille data is successfully written to electricity_price_WY.csv
# reading data for city: Cottage%20Grove. remaining cities: 201
# Cottage%20Grove data is successfully written to electricity_price_WY.csv
# reading data for city: Creswell. remaining cities: 200
# Creswell data is successfully written to electricity_price_WY.csv
# reading data for city: Days%20Creek. remaining cities: 199
# Days%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Deadwood. remaining cities: 198
# Deadwood data is successfully written to electricity_price_WY.csv
# reading data for city: Dexter. remaining cities: 197
# Dexter data is successfully written to electricity_price_WY.csv
# reading data for city: Dillard. remaining cities: 196
# Dillard data is successfully written to electricity_price_WY.csv
# reading data for city: Dorena. remaining cities: 195
# Dorena data is successfully written to electricity_price_WY.csv
# reading data for city: Drain. remaining cities: 194
# Drain data is successfully written to electricity_price_WY.csv
# reading data for city: Elkton. remaining cities: 193
# Elkton data is successfully written to electricity_price_WY.csv
# reading data for city: Elmira. remaining cities: 192
# Elmira data is successfully written to electricity_price_WY.csv
# reading data for city: Fall%20Creek. remaining cities: 191
# Fall%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Florence. remaining cities: 190
# Florence data is successfully written to electricity_price_WY.csv
# reading data for city: Gardiner. remaining cities: 189
# Gardiner data is successfully written to electricity_price_WY.csv
# reading data for city: Glendale. remaining cities: 188
# Glendale data is successfully written to electricity_price_WY.csv
# reading data for city: Glide. remaining cities: 187
# Glide data is successfully written to electricity_price_WY.csv
# reading data for city: Gold%20Beach. remaining cities: 186
# Gold%20Beach data is successfully written to electricity_price_WY.csv
# reading data for city: Harrisburg. remaining cities: 185
# Harrisburg data is successfully written to electricity_price_WY.csv
# reading data for city: Idleyld%20Park. remaining cities: 184
# Idleyld%20Park data is successfully written to electricity_price_WY.csv
# reading data for city: Junction%20City. remaining cities: 183
# Junction%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Lakeside. remaining cities: 182
# Lakeside data is successfully written to electricity_price_WY.csv
# reading data for city: Langlois. remaining cities: 181
# Langlois data is successfully written to electricity_price_WY.csv
# reading data for city: Lorane. remaining cities: 180
# Lorane data is successfully written to electricity_price_WY.csv
# reading data for city: Lowell. remaining cities: 179
# Lowell data is successfully written to electricity_price_WY.csv
# reading data for city: Mapleton. remaining cities: 178
# Mapleton data is successfully written to electricity_price_WY.csv
# reading data for city: Marcola. remaining cities: 177
# Marcola data is successfully written to electricity_price_WY.csv
# reading data for city: Pleasant%20Hill. remaining cities: 176
# Pleasant%20Hill data is successfully written to electricity_price_WY.csv
# reading data for city: Monroe. remaining cities: 175
# Monroe data is successfully written to electricity_price_WY.csv
# reading data for city: Myrtle%20Creek. remaining cities: 174
# Myrtle%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Myrtle%20Point. remaining cities: 173
# Myrtle%20Point data is successfully written to electricity_price_WY.csv
# reading data for city: North%20Bend. remaining cities: 172
# North%20Bend data is successfully written to electricity_price_WY.csv
# reading data for city: Noti. remaining cities: 171
# Noti data is successfully written to electricity_price_WY.csv
# reading data for city: Oakland. remaining cities: 170
# Oakland data is successfully written to electricity_price_WY.csv
# reading data for city: Oakridge. remaining cities: 169
# Oakridge data is successfully written to electricity_price_WY.csv
# reading data for city: Ophir. remaining cities: 168
# Ophir data is successfully written to electricity_price_WY.csv
# reading data for city: Port%20Orford. remaining cities: 167
# Port%20Orford data is successfully written to electricity_price_WY.csv
# reading data for city: Powers. remaining cities: 166
# Powers data is successfully written to electricity_price_WY.csv
# reading data for city: Reedsport. remaining cities: 165
# Reedsport data is successfully written to electricity_price_WY.csv
# reading data for city: Riddle. remaining cities: 164
# Riddle data is successfully written to electricity_price_WY.csv
# reading data for city: Roseburg. remaining cities: 163
# Roseburg data is successfully written to electricity_price_WY.csv
# reading data for city: Scottsburg. remaining cities: 162
# Scottsburg data is successfully written to electricity_price_WY.csv
# reading data for city: Springfield. remaining cities: 161
# Springfield data is successfully written to electricity_price_WY.csv
# reading data for city: Sixes. remaining cities: 160
# Sixes data is successfully written to electricity_price_WY.csv
# reading data for city: Sutherlin. remaining cities: 159
# Sutherlin data is successfully written to electricity_price_WY.csv
# reading data for city: Swisshome. remaining cities: 158
# Swisshome data is successfully written to electricity_price_WY.csv
# reading data for city: Tenmile. remaining cities: 157
# Tenmile data is successfully written to electricity_price_WY.csv
# reading data for city: Tiller. remaining cities: 156
# Tiller data is successfully written to electricity_price_WY.csv
# reading data for city: Umpqua. remaining cities: 155
# Umpqua data is successfully written to electricity_price_WY.csv
# reading data for city: Veneta. remaining cities: 154
# Veneta data is successfully written to electricity_price_WY.csv
# reading data for city: Vida. remaining cities: 153
# Vida data is successfully written to electricity_price_WY.csv
# reading data for city: Walterville. remaining cities: 152
# Walterville data is successfully written to electricity_price_WY.csv
# reading data for city: Walton. remaining cities: 151
# Walton data is successfully written to electricity_price_WY.csv
# reading data for city: Wedderburn. remaining cities: 150
# Wedderburn data is successfully written to electricity_price_WY.csv
# reading data for city: Westfir. remaining cities: 149
# Westfir data is successfully written to electricity_price_WY.csv
# reading data for city: Westlake. remaining cities: 148
# Westlake data is successfully written to electricity_price_WY.csv
# reading data for city: Wilbur. remaining cities: 147
# Wilbur data is successfully written to electricity_price_WY.csv
# reading data for city: Winchester. remaining cities: 146
# Winchester data is successfully written to electricity_price_WY.csv
# reading data for city: Winston. remaining cities: 145
# Winston data is successfully written to electricity_price_WY.csv
# reading data for city: Wolf%20Creek. remaining cities: 144
# Wolf%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Yachats. remaining cities: 143
# Yachats data is successfully written to electricity_price_WY.csv
# reading data for city: Yoncalla. remaining cities: 142
# Yoncalla data is successfully written to electricity_price_WY.csv
# reading data for city: Medford. remaining cities: 141
# Medford data is successfully written to electricity_price_WY.csv
# reading data for city: Central%20Point. remaining cities: 140
# Central%20Point data is successfully written to electricity_price_WY.csv
# reading data for city: White%20City. remaining cities: 139
# White%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Ashland. remaining cities: 138
# Ashland data is successfully written to electricity_price_WY.csv
# reading data for city: Butte%20Falls. remaining cities: 137
# Butte%20Falls data is successfully written to electricity_price_WY.csv
# reading data for city: Cave%20Junction. remaining cities: 136
# Cave%20Junction data is successfully written to electricity_price_WY.csv
# reading data for city: Eagle%20Point. remaining cities: 135
# Eagle%20Point data is successfully written to electricity_price_WY.csv
# reading data for city: Gold%20Hill. remaining cities: 134
# Gold%20Hill data is successfully written to electricity_price_WY.csv
# reading data for city: Grants%20Pass. remaining cities: 133
# Grants%20Pass data is successfully written to electricity_price_WY.csv
# reading data for city: Jacksonville. remaining cities: 132
# Jacksonville data is successfully written to electricity_price_WY.csv
# reading data for city: Kerby. remaining cities: 131
# Kerby data is successfully written to electricity_price_WY.csv
# reading data for city: Merlin. remaining cities: 130
# Merlin data is successfully written to electricity_price_WY.csv
# reading data for city: Murphy. remaining cities: 129
# Murphy data is successfully written to electricity_price_WY.csv
# reading data for city: O%20Brien. remaining cities: 128
# O%20Brien data is successfully written to electricity_price_WY.csv
# reading data for city: Phoenix. remaining cities: 127
# Phoenix data is successfully written to electricity_price_WY.csv
# reading data for city: Prospect. remaining cities: 126
# Prospect data is successfully written to electricity_price_WY.csv
# reading data for city: Rogue%20River. remaining cities: 125
# Rogue%20River data is successfully written to electricity_price_WY.csv
# reading data for city: Selma. remaining cities: 124
# Selma data is successfully written to electricity_price_WY.csv
# reading data for city: Shady%20Cove. remaining cities: 123
# Shady%20Cove data is successfully written to electricity_price_WY.csv
# reading data for city: Talent. remaining cities: 122
# Talent data is successfully written to electricity_price_WY.csv
# reading data for city: Trail. remaining cities: 121
# Trail data is successfully written to electricity_price_WY.csv
# reading data for city: Wilderville. remaining cities: 120
# Wilderville data is successfully written to electricity_price_WY.csv
# reading data for city: Williams. remaining cities: 119
# Williams data is successfully written to electricity_price_WY.csv
# reading data for city: Klamath%20Falls. remaining cities: 118
# Klamath%20Falls data is successfully written to electricity_price_WY.csv
# reading data for city: Crater%20Lake. remaining cities: 117
# Crater%20Lake data is successfully written to electricity_price_WY.csv
# reading data for city: Adel. remaining cities: 116
# Adel data is successfully written to electricity_price_WY.csv
# reading data for city: Beatty. remaining cities: 115
# Beatty data is successfully written to electricity_price_WY.csv
# reading data for city: Bly. remaining cities: 114
# Bly data is successfully written to electricity_price_WY.csv
# reading data for city: Bonanza. remaining cities: 113
# Bonanza data is successfully written to electricity_price_WY.csv
# reading data for city: Chiloquin. remaining cities: 112
# Chiloquin data is successfully written to electricity_price_WY.csv
# reading data for city: Dairy. remaining cities: 111
# Dairy data is successfully written to electricity_price_WY.csv
# reading data for city: Fort%20Klamath. remaining cities: 110
# Fort%20Klamath data is successfully written to electricity_price_WY.csv
# reading data for city: Keno. remaining cities: 109
# Keno data is successfully written to electricity_price_WY.csv
# reading data for city: Lakeview. remaining cities: 108
# Lakeview data is successfully written to electricity_price_WY.csv
# reading data for city: Malin. remaining cities: 107
# Malin data is successfully written to electricity_price_WY.csv
# reading data for city: Merrill. remaining cities: 106
# Merrill data is successfully written to electricity_price_WY.csv
# reading data for city: Midland. remaining cities: 105
# Midland data is successfully written to electricity_price_WY.csv
# reading data for city: New%20Pine%20Creek. remaining cities: 104
# New%20Pine%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Paisley. remaining cities: 103
# Paisley data is successfully written to electricity_price_WY.csv
# reading data for city: Plush. remaining cities: 102
# Plush data is successfully written to electricity_price_WY.csv
# reading data for city: Silver%20Lake. remaining cities: 101
# Silver%20Lake data is successfully written to electricity_price_WY.csv
# reading data for city: Sprague%20River. remaining cities: 100
# Sprague%20River data is successfully written to electricity_price_WY.csv
# reading data for city: Summer%20Lake. remaining cities: 99
# Summer%20Lake data is successfully written to electricity_price_WY.csv
# reading data for city: Christmas%20Valley. remaining cities: 98
# Christmas%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Bend. remaining cities: 97
# Bend data is successfully written to electricity_price_WY.csv
# reading data for city: Fields. remaining cities: 96
# Fields data is successfully written to electricity_price_WY.csv
# reading data for city: Ashwood. remaining cities: 95
# Ashwood data is successfully written to electricity_price_WY.csv
# reading data for city: Brothers. remaining cities: 94
# Brothers data is successfully written to electricity_price_WY.csv
# reading data for city: Burns. remaining cities: 93
# Burns data is successfully written to electricity_price_WY.csv
# reading data for city: Princeton. remaining cities: 92
# Princeton data is successfully written to electricity_price_WY.csv
# reading data for city: Diamond. remaining cities: 91
# Diamond data is successfully written to electricity_price_WY.csv
# reading data for city: Camp%20Sherman. remaining cities: 90
# Camp%20Sherman data is successfully written to electricity_price_WY.csv
# reading data for city: Chemult. remaining cities: 89
# Chemult data is successfully written to electricity_price_WY.csv
# reading data for city: Crane. remaining cities: 88
# Crane data is successfully written to electricity_price_WY.csv
# reading data for city: Crescent. remaining cities: 87
# Crescent data is successfully written to electricity_price_WY.csv
# reading data for city: Culver. remaining cities: 86
# Culver data is successfully written to electricity_price_WY.csv
# reading data for city: Fort%20Rock. remaining cities: 85
# Fort%20Rock data is successfully written to electricity_price_WY.csv
# reading data for city: Frenchglen. remaining cities: 84
# Frenchglen data is successfully written to electricity_price_WY.csv
# reading data for city: Gilchrist. remaining cities: 83
# Gilchrist data is successfully written to electricity_price_WY.csv
# reading data for city: Hines. remaining cities: 82
# Hines data is successfully written to electricity_price_WY.csv
# reading data for city: La%20Pine. remaining cities: 81
# La%20Pine data is successfully written to electricity_price_WY.csv
# reading data for city: Madras. remaining cities: 80
# Madras data is successfully written to electricity_price_WY.csv
# reading data for city: Mitchell. remaining cities: 79
# Mitchell data is successfully written to electricity_price_WY.csv
# reading data for city: Paulina. remaining cities: 78
# Paulina data is successfully written to electricity_price_WY.csv
# reading data for city: Post. remaining cities: 77
# Post data is successfully written to electricity_price_WY.csv
# reading data for city: Powell%20Butte. remaining cities: 76
# Powell%20Butte data is successfully written to electricity_price_WY.csv
# reading data for city: Prineville. remaining cities: 75
# Prineville data is successfully written to electricity_price_WY.csv
# reading data for city: Redmond. remaining cities: 74
# Redmond data is successfully written to electricity_price_WY.csv
# reading data for city: Riley. remaining cities: 73
# Riley data is successfully written to electricity_price_WY.csv
# reading data for city: Sisters. remaining cities: 72
# Sisters data is successfully written to electricity_price_WY.csv
# reading data for city: Terrebonne. remaining cities: 71
# Terrebonne data is successfully written to electricity_price_WY.csv
# reading data for city: Warm%20Springs. remaining cities: 70
# Warm%20Springs data is successfully written to electricity_price_WY.csv
# reading data for city: Pendleton. remaining cities: 69
# Pendleton data is successfully written to electricity_price_WY.csv
# reading data for city: Adams. remaining cities: 68
# Adams data is successfully written to electricity_price_WY.csv
# reading data for city: Arlington. remaining cities: 67
# Arlington data is successfully written to electricity_price_WY.csv
# reading data for city: Athena. remaining cities: 66
# Athena data is successfully written to electricity_price_WY.csv
# reading data for city: Baker%20City. remaining cities: 65
# Baker%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Bates. remaining cities: 64
# Bates data is successfully written to electricity_price_WY.csv
# reading data for city: Boardman. remaining cities: 63
# Boardman data is successfully written to electricity_price_WY.csv
# reading data for city: Bridgeport. remaining cities: 62
# Bridgeport data is successfully written to electricity_price_WY.csv
# reading data for city: Canyon%20City. remaining cities: 61
# Canyon%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Condon. remaining cities: 60
# Condon data is successfully written to electricity_price_WY.csv
# reading data for city: Cove. remaining cities: 59
# Cove data is successfully written to electricity_price_WY.csv
# reading data for city: Dayville. remaining cities: 58
# Dayville data is successfully written to electricity_price_WY.csv
# reading data for city: Echo. remaining cities: 57
# Echo data is successfully written to electricity_price_WY.csv
# reading data for city: Elgin. remaining cities: 56
# Elgin data is successfully written to electricity_price_WY.csv
# reading data for city: Enterprise. remaining cities: 55
# Enterprise data is successfully written to electricity_price_WY.csv
# reading data for city: Fossil. remaining cities: 54
# Fossil data is successfully written to electricity_price_WY.csv
# reading data for city: Haines. remaining cities: 53
# Haines data is successfully written to electricity_price_WY.csv
# reading data for city: Halfway. remaining cities: 52
# Halfway data is successfully written to electricity_price_WY.csv
# reading data for city: Helix. remaining cities: 51
# Helix data is successfully written to electricity_price_WY.csv
# reading data for city: Heppner. remaining cities: 50
# Heppner data is successfully written to electricity_price_WY.csv
# reading data for city: Hereford. remaining cities: 49
# Hereford data is successfully written to electricity_price_WY.csv
# reading data for city: Hermiston. remaining cities: 48
# Hermiston data is successfully written to electricity_price_WY.csv
# reading data for city: Lexington. remaining cities: 47
# Lexington data is successfully written to electricity_price_WY.csv
# reading data for city: Oxbow. remaining cities: 46
# Oxbow data is successfully written to electricity_price_WY.csv
# reading data for city: Imbler. remaining cities: 45
# Imbler data is successfully written to electricity_price_WY.csv
# reading data for city: Imnaha. remaining cities: 44
# Imnaha data is successfully written to electricity_price_WY.csv
# reading data for city: Ione. remaining cities: 43
# Ione data is successfully written to electricity_price_WY.csv
# reading data for city: Irrigon. remaining cities: 42
# Irrigon data is successfully written to electricity_price_WY.csv
# reading data for city: John%20Day. remaining cities: 41
# John%20Day data is successfully written to electricity_price_WY.csv
# reading data for city: Joseph. remaining cities: 40
# Joseph data is successfully written to electricity_price_WY.csv
# reading data for city: Kimberly. remaining cities: 39
# Kimberly data is successfully written to electricity_price_WY.csv
# reading data for city: La%20Grande. remaining cities: 38
# La%20Grande data is successfully written to electricity_price_WY.csv
# reading data for city: Long%20Creek. remaining cities: 37
# Long%20Creek data is successfully written to electricity_price_WY.csv
# reading data for city: Lostine. remaining cities: 36
# Lostine data is successfully written to electricity_price_WY.csv
# reading data for city: Meacham. remaining cities: 35
# Meacham data is successfully written to electricity_price_WY.csv
# reading data for city: Mikkalo. remaining cities: 34
# Mikkalo data is successfully written to electricity_price_WY.csv
# reading data for city: Milton%20Freewater. remaining cities: 33
# Milton%20Freewater data is successfully written to electricity_price_WY.csv
# reading data for city: Monument. remaining cities: 32
# Monument data is successfully written to electricity_price_WY.csv
# reading data for city: Mount%20Vernon. remaining cities: 31
# Mount%20Vernon data is successfully written to electricity_price_WY.csv
# reading data for city: North%20Powder. remaining cities: 30
# North%20Powder data is successfully written to electricity_price_WY.csv
# reading data for city: Pilot%20Rock. remaining cities: 29
# Pilot%20Rock data is successfully written to electricity_price_WY.csv
# reading data for city: Prairie%20City. remaining cities: 28
# Prairie%20City data is successfully written to electricity_price_WY.csv
# reading data for city: Richland. remaining cities: 27
# Richland data is successfully written to electricity_price_WY.csv
# reading data for city: Seneca. remaining cities: 26
# Seneca data is successfully written to electricity_price_WY.csv
# reading data for city: Spray. remaining cities: 25
# Spray data is successfully written to electricity_price_WY.csv
# reading data for city: Stanfield. remaining cities: 24
# Stanfield data is successfully written to electricity_price_WY.csv
# reading data for city: Summerville. remaining cities: 23
# Summerville data is successfully written to electricity_price_WY.csv
# reading data for city: Sumpter. remaining cities: 22
# Sumpter data is successfully written to electricity_price_WY.csv
# reading data for city: Ukiah. remaining cities: 21
# Ukiah data is successfully written to electricity_price_WY.csv
# reading data for city: Umatilla. remaining cities: 20
# Umatilla data is successfully written to electricity_price_WY.csv
# reading data for city: Union. remaining cities: 19
# Union data is successfully written to electricity_price_WY.csv
# reading data for city: Unity. remaining cities: 18
# Unity data is successfully written to electricity_price_WY.csv
# reading data for city: Wallowa. remaining cities: 17
# Wallowa data is successfully written to electricity_price_WY.csv
# reading data for city: Weston. remaining cities: 16
# Weston data is successfully written to electricity_price_WY.csv
# reading data for city: Adrian. remaining cities: 15
# Adrian data is successfully written to electricity_price_WY.csv
# reading data for city: Arock. remaining cities: 14
# Arock data is successfully written to electricity_price_WY.csv
# reading data for city: Brogan. remaining cities: 13
# Brogan data is successfully written to electricity_price_WY.csv
# reading data for city: Drewsey. remaining cities: 12
# Drewsey data is successfully written to electricity_price_WY.csv
# reading data for city: Durkee. remaining cities: 11
# Durkee data is successfully written to electricity_price_WY.csv
# reading data for city: Harper. remaining cities: 10
# Harper data is successfully written to electricity_price_WY.csv
# reading data for city: Huntington. remaining cities: 9
# Huntington data is successfully written to electricity_price_WY.csv
# reading data for city: Ironside. remaining cities: 8
# Ironside data is successfully written to electricity_price_WY.csv
# reading data for city: Jamieson. remaining cities: 7
# Jamieson data is successfully written to electricity_price_WY.csv
# reading data for city: Jordan%20Valley. remaining cities: 6
# Jordan%20Valley data is successfully written to electricity_price_WY.csv
# reading data for city: Juntura. remaining cities: 5
# Juntura data is successfully written to electricity_price_WY.csv
# reading data for city: Nyssa. remaining cities: 4
# Nyssa data is successfully written to electricity_price_WY.csv
# reading data for city: Ontario. remaining cities: 3
# Ontario data is successfully written to electricity_price_WY.csv
# reading data for city: Riverside. remaining cities: 2
# Riverside data is successfully written to electricity_price_WY.csv
# reading data for city: Vale. remaining cities: 1
# Vale data is successfully written to electricity_price_WY.csv
# reading data for city: Westfall. remaining cities: 0
# Westfall data is successfully written to electricity_price_WY.csv

# %% [markdown]
# Read retrieved data

# %%
electricity.prices = read_csv("data/electricity_price_OR_re.csv")
electricity.prices
# Out:
# Parsed with column specification:
# cols(
#   inputs.address = col_character(),
#   version = col_character(),
#   metadata.sources = col_character(),
#   outputs.company_id = col_character(),
#   outputs.utility_name = col_character(),
#   outputs.utility_info.company_id = col_character(),
#   outputs.utility_info.utility_name = col_character(),
#   outputs.commercial = col_character(),
#   outputs.industrial = col_character(),
#   outputs.residential = col_character()
# )
# Warning message in rbind(names(probs), probs_f):
# “number of columns of result is not a multiple of vector length (arg 1)”Warning message:
# “69 parsing failures.
# row # A tibble: 5 x 5 col     row   col   expected    actual                               file expected   <int> <chr>      <chr>     <chr>                              <chr> actual 1     6  <NA> 10 columns 8 columns 'data/electricity_price_OR_re.csv' file 2    15  <NA> 10 columns 8 columns 'data/electricity_price_OR_re.csv' row 3    21  <NA> 10 columns 8 columns 'data/electricity_price_OR_re.csv' col 4    32  <NA> 10 columns 8 columns 'data/electricity_price_OR_re.csv' expected 5    36  <NA> 10 columns 8 columns 'data/electricity_price_OR_re.csv'
# ... ................. ... ..................................................................... ........ ..................................................................... ...... ..................................................................... .... ..................................................................... ... ..................................................................... ... ..................................................................... ........ .....................................................................
# See problems(...) for more details.
# ”
#     inputs.address version metadata.sources       outputs.company_id
# 1   Antelope       3.1.0   Ventyx Research (2012) 20138
# 2   Aurora         3.1.0   Ventyx Research (2012) 4110
# 3   Beaverton      3.1.0   Ventyx Research (2012) 15248
# 4   Beavercreek    3.1.0   Ventyx Research (2012) 4922
# 5   Boring         3.1.0   Ventyx Research (2012) 15248
# 6   Bridal Veil    3.1.0   Ventyx Research (2012) no data
# 7   Brightwood     3.1.0   Ventyx Research (2012) 15248
# 8   Canby          3.1.0   Ventyx Research (2012) 2955
# 9   Cascade Locks  3.1.0   Ventyx Research (2012) 3136
# 10  Clackamas      3.1.0   Ventyx Research (2012) 15248
# ⋮   ⋮              ⋮       ⋮                      ⋮
# 364 Huntington     3.1.0   Ventyx Research (2012) 733
# 365 Ironside       3.1.0   Ventyx Research (2012) 9191
# 366 Jamieson       3.1.0   Ventyx Research (2012) no data
# 367 Jordan Valley  3.1.0   Ventyx Research (2012) 9191
# 368 Juntura        3.1.0   Ventyx Research (2012) 9191
# 369 Nyssa          3.1.0   Ventyx Research (2012) 9191
# 370 Ontario        3.1.0   Ventyx Research (2012) NA
# 371 Riverside      3.1.0   Ventyx Research (2012) 4110
# 372 Vale           3.1.0   Ventyx Research (2012) no data
# 373 Westfall       3.1.0   Ventyx Research (2012) 22500
#     outputs.utility_name          outputs.utility_info.company_id
# 1   Wasco Electric Coop Inc       20138
# 2   Commonwealth Edison Co        4110
# 3   Portland General Electric Co  15248
# 4   Dayton Power & Light Co (The) 4922
# 5   Portland General Electric Co  15248
# 6   no data                       0.0831
# 7   Portland General Electric Co  15248
# 8   Canby Utility Board           2955
# 9   Cascade Locks OR (City of)    3136
# 10  Portland General Electric Co  15248
# ⋮   ⋮                             ⋮
# 364 Appalachian Power Co          733
# 365 Idaho Power Co                9191
# 366 no data                       no data
# 367 Idaho Power Co                9191
# 368 Idaho Power Co                9191
# 369 Idaho Power Co                9191
# 370 Thunder Bay Hydro             NA
# 371 Commonwealth Edison Co        4110
# 372 no data                       no data
# 373 Westar Energy Inc             22500
#     outputs.utility_info.utility_name outputs.commercial outputs.industrial
# 1   Wasco Electric Coop Inc           0.0966             0.0739
# 2   Commonwealth Edison Co            0.0405             0.0139
# 3   Portland General Electric Co      0.0845             0.0535
# 4   Dayton Power & Light Co (The)     0.0483             0.0196
# 5   Portland General Electric Co      0.0845             0.0535
# 6   0.0559                            0.098              NA
# 7   Portland General Electric Co      0.0845             0.0535
# 8   Canby Utility Board               0.051              0.0532
# 9   Cascade Locks OR (City of)        0.0807             0.0559
# 10  Portland General Electric Co      0.0845             0.0535
# ⋮   ⋮                                 ⋮                  ⋮
# 364 Appalachian Power Co              0.0847             0.0649
# 365 Idaho Power Co                    0.0729             0.0589
# 366 no data                           no data            NA
# 367 Idaho Power Co                    0.0729             0.0589
# 368 Idaho Power Co                    0.0729             0.0589
# 369 Idaho Power Co                    0.0729             0.0589
# 370 Thunder Bay Hydro                 no data            no data
# 371 Commonwealth Edison Co            0.0405             0.0139
# 372 no data                           no data            NA
# 373 Westar Energy Inc                 0.0851             0.0714
#     outputs.residential
# 1   0.0956
# 2   0.1044
# 3   0.1072
# 4   0.1179
# 5   0.1072
# 6   NA
# 7   0.1072
# 8   0.0641
# 9   0.0878
# 10  0.1072
# ⋮   ⋮
# 364 0.0957
# 365 0.0883
# 366 NA
# 367 0.0883
# 368 0.0883
# 369 0.0883
# 370 no data
# 371 0.1044
# 372 NA
# 373 0.107

# %% [markdown]
# Show problems

# %%
summary(as.factor(problems(electricity.prices)$actual))
# Out:
# 12 columns  8 columns
#         27         42

# %% [markdown]
# The "12 columns" means the places have multiple utility company info casusing column mismatch, and the "8 columns" means no info.

# %%
problem.rows = problems(electricity.prices) %>%
    filter(actual == '12 columns') %>%
    .$row

# %% [markdown]
# Retrieve again for problem rows.

# %%
cities.retry = electricity.prices %>%
    filter(row_number() %in% problem.rows) %>%
    .$inputs.address

# %% [markdown]
# ### Skip next line if the data has already been retrieved.

# %%
get_electricity_prices(cities.retry)
# Out:
# reading data for city: Cornelius. remaining cities: 26
# Cornelius data is successfully written to electricity_price_WY.csv
# reading data for city: Lafayette. remaining cities: 25
# Lafayette data is successfully written to electricity_price_WY.csv
# reading data for city: Sherwood. remaining cities: 24
# Sherwood data is successfully written to electricity_price_WY.csv
# reading data for city: Eddyville. remaining cities: 23
# Eddyville data is successfully written to electricity_price_WY.csv
# reading data for city: Azalea. remaining cities: 22
# Azalea data is successfully written to electricity_price_WY.csv
# reading data for city: Canyonville. remaining cities: 21
# Canyonville data is successfully written to electricity_price_WY.csv
# reading data for city: Days Creek. remaining cities: 20
# Days Creek data retrieving failed
# reading data for city: Dexter. remaining cities: 19
# Dexter data is successfully written to electricity_price_WY.csv
# reading data for city: Fall Creek. remaining cities: 18
# Fall Creek data retrieving failed
# reading data for city: Myrtle Creek. remaining cities: 17
# Myrtle Creek data retrieving failed
# reading data for city: Oakridge. remaining cities: 16
# Oakridge data is successfully written to electricity_price_WY.csv
# reading data for city: Riddle. remaining cities: 15
# Riddle data is successfully written to electricity_price_WY.csv
# reading data for city: Roseburg. remaining cities: 14
# Roseburg data is successfully written to electricity_price_WY.csv
# reading data for city: Medford. remaining cities: 13
# Medford data is successfully written to electricity_price_WY.csv
# reading data for city: Murphy. remaining cities: 12
# Murphy data is successfully written to electricity_price_WY.csv
# reading data for city: Talent. remaining cities: 11
# Talent data is successfully written to electricity_price_WY.csv
# reading data for city: Klamath Falls. remaining cities: 10
# Klamath Falls data retrieving failed
# reading data for city: Chiloquin. remaining cities: 9
# Chiloquin data is successfully written to electricity_price_WY.csv
# reading data for city: Midland. remaining cities: 8
# Midland data is successfully written to electricity_price_WY.csv
# reading data for city: New Pine Creek. remaining cities: 7
# New Pine Creek data retrieving failed
# reading data for city: Haines. remaining cities: 6
# Haines data is successfully written to electricity_price_WY.csv
# reading data for city: Hermiston. remaining cities: 5
# Hermiston data is successfully written to electricity_price_WY.csv
# reading data for city: Kimberly. remaining cities: 4
# Kimberly data is successfully written to electricity_price_WY.csv
# reading data for city: La Grande. remaining cities: 3
# La Grande data retrieving failed
# reading data for city: Seneca. remaining cities: 2
# Seneca data is successfully written to electricity_price_WY.csv
# reading data for city: Union. remaining cities: 1
# Union data is successfully written to electricity_price_WY.csv
# reading data for city: Adrian. remaining cities: 0
# Adrian data is successfully written to electricity_price_WY.csv

# %% [markdown]
# Read retried files

# %%
electricity.prices.retried = read_csv('data/electricity_price_OR_re.csv')
head(electricity.prices.retried)
# Out:
# Parsed with column specification:
# cols(
#   inputs.address = col_character(),
#   version = col_character(),
#   metadata.sources = col_character(),
#   outputs.company_id = col_character(),
#   outputs.utility_name = col_character(),
#   outputs.utility_info.company_id1 = col_integer(),
#   outputs.utility_info.company_id2 = col_integer(),
#   outputs.utility_info.utility_name1 = col_character(),
#   outputs.utility_info.utility_name2 = col_character(),
#   outputs.commercial = col_double(),
#   outputs.industrial = col_double(),
#   outputs.residential = col_double()
# )
#   inputs.address version metadata.sources       outputs.company_id
# 1 Cornelius      3.1.0   Ventyx Research (2012) 4365|5416
# 2 Lafayette      3.1.0   Ventyx Research (2012) 55936|9096
# 3 Sherwood       3.1.0   Ventyx Research (2012) 814|13718
# 4 Eddyville      3.1.0   Ventyx Research (2012) 10171|18642
# 5 Azalea         3.1.0   Ventyx Research (2012) 20169|14354
# 6 Canyonville    3.1.0   Ventyx Research (2012) 20169|14354
#   outputs.utility_name
# 1 Cornelius NC (City of)|Duke Energy Carolinas
# 2 Entergy Gulf States Louisiana LLC|Lafayette Utilities System
# 3 Entergy Arkansas Inc|North Little Rock AR (City of)
# 4 Kentucky Utilities Co|Tennessee Valley Authority
# 5 Avista Corp|PacifiCorp
# 6 Avista Corp|PacifiCorp
#   outputs.utility_info.company_id1 outputs.utility_info.company_id2
# 1  4365                             5416
# 2 55936                             9096
# 3   814                            13718
# 4 10171                            18642
# 5 20169                            14354
# 6 20169                            14354
#   outputs.utility_info.utility_name1 outputs.utility_info.utility_name2
# 1 Cornelius NC (City of)             Duke Energy Carolinas
# 2 Entergy Gulf States Louisiana LLC  Lafayette Utilities System
# 3 Entergy Arkansas Inc               North Little Rock AR (City of)
# 4 Kentucky Utilities Co              Tennessee Valley Authority
# 5 Avista Corp                        PacifiCorp
# 6 Avista Corp                        PacifiCorp
#   outputs.commercial outputs.industrial outputs.residential
# 1 0.0882             0.0630             0.1000
# 2 0.0753             0.0458             0.0796
# 3 0.0885             0.0736             0.1018
# 4 0.0841             0.0504             0.0883
# 5 0.0843             0.0675             0.1038
# 6 0.0843             0.0675             0.1038

# %% [markdown]
# Remove error rows of the raw file and combine with the retried file.

# %%
as.numeric('no data')
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# [1] NA

# %%
electricity.prices.cleaned = electricity.prices %>%
    filter(!(row_number() %in% problems(electricity.prices)$row)) %>%
    mutate(outputs.commercial = as.numeric(outputs.commercial), 
           outputs.industrial = as.numeric(outputs.industrial),
           outputs.residential = as.numeric(outputs.residential))

electricity.prices = electricity.prices.cleaned %>%
    select(address=inputs.address, commercial=outputs.commercial, industrial=outputs.industrial, residential=outputs.residential,
           source=metadata.sources, version, company_id=outputs.company_id, utility_name=outputs.utility_name) %>%
    bind_rows(electricity.prices.retried %>%
                  select(address=inputs.address, commercial=outputs.commercial, industrial=outputs.industrial, residential=outputs.residential,
                         source=metadata.sources, version, company_id=outputs.company_id, utility_name=outputs.utility_name))
electricity.prices
# Out:
# Warning message in evalq(as.numeric(outputs.commercial), <environment>):
# “NAs introduced by coercion”Warning message in evalq(as.numeric(outputs.industrial), <environment>):
# “NAs introduced by coercion”Warning message in evalq(as.numeric(outputs.residential), <environment>):
# “NAs introduced by coercion”
#     address       commercial industrial residential source
# 1   Antelope      0.0966     0.0739     0.0956      Ventyx Research (2012)
# 2   Aurora        0.0405     0.0139     0.1044      Ventyx Research (2012)
# 3   Beaverton     0.0845     0.0535     0.1072      Ventyx Research (2012)
# 4   Beavercreek   0.0483     0.0196     0.1179      Ventyx Research (2012)
# 5   Boring        0.0845     0.0535     0.1072      Ventyx Research (2012)
# 6   Brightwood    0.0845     0.0535     0.1072      Ventyx Research (2012)
# 7   Canby         0.0510     0.0532     0.0641      Ventyx Research (2012)
# 8   Cascade Locks 0.0807     0.0559     0.0878      Ventyx Research (2012)
# 9   Clackamas     0.0845     0.0535     0.1072      Ventyx Research (2012)
# 10  Clatskanie    0.0514     0.0426     0.0484      Ventyx Research (2012)
# ⋮   ⋮             ⋮          ⋮          ⋮           ⋮
# 316 Murphy        0.1028     0.0915     0.1121      Ventyx Research (2012)
# 317 Talent        0.0843     0.0675     0.1038      Ventyx Research (2012)
# 318 Chiloquin     0.0843     0.0675     0.1038      Ventyx Research (2012)
# 319 Midland       0.0776     0.0570     0.0938      Ventyx Research (2012)
# 320 Haines        0.3935     0.3976     0.4726      Ventyx Research (2012)
# 321 Hermiston     0.0635     0.0518     0.0739      Ventyx Research (2012)
# 322 Kimberly      0.1067     0.0569     0.1157      Ventyx Research (2012)
# 323 Seneca        0.0957     0.0777     0.1068      Ventyx Research (2012)
# 324 Union         0.0934     0.0735     0.1048      Ventyx Research (2012)
# 325 Adrian        0.0965     0.0713     0.1429      Ventyx Research (2012)
#     version company_id
# 1   3.1.0   20138
# 2   3.1.0   4110
# 3   3.1.0   15248
# 4   3.1.0   4922
# 5   3.1.0   15248
# 6   3.1.0   15248
# 7   3.1.0   2955
# 8   3.1.0   3136
# 9   3.1.0   15248
# 10  3.1.0   28541
# ⋮   ⋮       ⋮
# 316 3.1.0   40441|18642
# 317 3.1.0   20169|14354
# 318 3.1.0   20169|14354
# 319 3.1.0   6203
# 320 3.1.0   219|18963
# 321 3.1.0   8515|19325
# 322 3.1.0   195|18642
# 323 3.1.0   5416|16921
# 324 3.1.0   5416|19431
# 325 3.1.0   4254|12377
#     utility_name
# 1   Wasco Electric Coop Inc
# 2   Commonwealth Edison Co
# 3   Portland General Electric Co
# 4   Dayton Power & Light Co (The)
# 5   Portland General Electric Co
# 6   Portland General Electric Co
# 7   Canby Utility Board
# 8   Cascade Locks OR (City of)
# 9   Portland General Electric Co
# 10  Clatskanie Peoples Utility District
# ⋮   ⋮
# 316 Murphy Electric Power NC (Town of)|Tennessee Valley Authority
# 317 Avista Corp|PacifiCorp
# 318 Avista Corp|PacifiCorp
# 319 Farmersville TX (City of)|TXU Energy Retail Co LP
# 320 Alaska Power Co|Inside Passage Electric Coop
# 321 Hermiston OR (City of)|Umatilla Electric Coop
# 322 Alabama Power Co|Tennessee Valley Authority
# 323 Duke Energy Carolinas|Seneca SC (City of)
# 324 Duke Energy Carolinas|Union Utility Dept
# 325 Consumers Energy Co|Midwest Energy Coop

# %% [markdown]
# Top 10 across two states ranked by commercial, industrial, residential

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    arrange(commercial, industrial, residential) %>%
    head(20)
# Out:
#    address      commercial industrial residential source
# 1  Harrisburg   0.0276     0.0064     0.0820      Ventyx Research (2012)
# 2  Amity        0.0337     0.0112     0.0746      Ventyx Research (2012)
# 3  Gilchrist    0.0363     0.0077     0.0906      Ventyx Research (2012)
# 4  Mount Vernon 0.0363     0.0077     0.0906      Ventyx Research (2012)
# 5  Beaver       0.0372     0.0135     0.1144      Ventyx Research (2012)
# 6  Aurora       0.0405     0.0139     0.1044      Ventyx Research (2012)
# 7  Lyons        0.0405     0.0139     0.1044      Ventyx Research (2012)
# 8  Silver Lake  0.0405     0.0139     0.1044      Ventyx Research (2012)
# 9  Elgin        0.0405     0.0139     0.1044      Ventyx Research (2012)
# 10 Riverside    0.0405     0.0139     0.1044      Ventyx Research (2012)
# 11 Gardiner     0.0415     0.0228     0.0694      Ventyx Research (2012)
# 12 Kent         0.0460     0.0218     0.0735      Ventyx Research (2012)
# 13 Boardman     0.0460     0.0218     0.0735      Ventyx Research (2012)
# 14 Beavercreek  0.0483     0.0196     0.1179      Ventyx Research (2012)
# 15 Dayton       0.0483     0.0196     0.1179      Ventyx Research (2012)
# 16 Elkton       0.0494     0.0158     0.1196      Ventyx Research (2012)
# 17 Elmira       0.0494     0.0208     0.0924      Ventyx Research (2012)
# 18 Westlake     0.0508     0.0167     0.0678      Ventyx Research (2012)
# 19 Canby        0.0510     0.0532     0.0641      Ventyx Research (2012)
# 20 Clatskanie   0.0514     0.0426     0.0484      Ventyx Research (2012)
#    version company_id utility_name                             State
# 1  3.1.0   14715      PPL Electric Utilities Corp              Oregon
# 2  3.1.0   20387      West Penn Power Co                       Oregon
# 3  3.1.0   NA         AmerenCIPS                               Oregon
# 4  3.1.0   NA         AmerenIP                                 Oregon
# 5  3.1.0   5487       Duquesne Light Co                        Oregon
# 6  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 7  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 8  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 9  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 10 3.1.0   4110       Commonwealth Edison Co                   Oregon
# 11 3.1.0   3266       Central Maine Power Co                   Oregon
# 12 3.1.0   13998      Ohio Edison Co                           Oregon
# 13 3.1.0   13998      Ohio Edison Co                           Oregon
# 14 3.1.0   4922       Dayton Power & Light Co (The)            Oregon
# 15 3.1.0   4922       Dayton Power & Light Co (The)            Oregon
# 16 3.1.0   5027       Delmarva Power & Light Co                Oregon
# 17 3.1.0   13511      New York State Electric & Gas Corp       Oregon
# 18 3.1.0   3755       Cleveland Electric Illuminating Co (The) Oregon
# 19 3.1.0   2955       Canby Utility Board                      Oregon
# 20 3.1.0   28541      Clatskanie Peoples Utility District      Oregon

# %% [markdown]
# Top 10 across two states ranked by industrial, commercial, residential

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    arrange(industrial, commercial, residential) %>%
    head(20)
# Out:
#    address      commercial industrial residential source
# 1  Harrisburg   0.0276     0.0064     0.0820      Ventyx Research (2012)
# 2  Gilchrist    0.0363     0.0077     0.0906      Ventyx Research (2012)
# 3  Mount Vernon 0.0363     0.0077     0.0906      Ventyx Research (2012)
# 4  Amity        0.0337     0.0112     0.0746      Ventyx Research (2012)
# 5  Beaver       0.0372     0.0135     0.1144      Ventyx Research (2012)
# 6  Aurora       0.0405     0.0139     0.1044      Ventyx Research (2012)
# 7  Lyons        0.0405     0.0139     0.1044      Ventyx Research (2012)
# 8  Silver Lake  0.0405     0.0139     0.1044      Ventyx Research (2012)
# 9  Elgin        0.0405     0.0139     0.1044      Ventyx Research (2012)
# 10 Riverside    0.0405     0.0139     0.1044      Ventyx Research (2012)
# 11 Lorane       0.0561     0.0141     0.1095      Ventyx Research (2012)
# 12 Toledo       0.0519     0.0155     0.0758      Ventyx Research (2012)
# 13 Elkton       0.0494     0.0158     0.1196      Ventyx Research (2012)
# 14 Westlake     0.0508     0.0167     0.0678      Ventyx Research (2012)
# 15 Alvadore     0.0859     0.0184     0.0848      Ventyx Research (2012)
# 16 Marcola      0.0859     0.0184     0.0848      Ventyx Research (2012)
# 17 Veneta       0.0859     0.0184     0.0848      Ventyx Research (2012)
# 18 Beavercreek  0.0483     0.0196     0.1179      Ventyx Research (2012)
# 19 Dayton       0.0483     0.0196     0.1179      Ventyx Research (2012)
# 20 Elmira       0.0494     0.0208     0.0924      Ventyx Research (2012)
#    version company_id utility_name                             State
# 1  3.1.0   14715      PPL Electric Utilities Corp              Oregon
# 2  3.1.0   NA         AmerenCIPS                               Oregon
# 3  3.1.0   NA         AmerenIP                                 Oregon
# 4  3.1.0   20387      West Penn Power Co                       Oregon
# 5  3.1.0   5487       Duquesne Light Co                        Oregon
# 6  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 7  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 8  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 9  3.1.0   4110       Commonwealth Edison Co                   Oregon
# 10 3.1.0   4110       Commonwealth Edison Co                   Oregon
# 11 3.1.0   12390      Metropolitan Edison Co                   Oregon
# 12 3.1.0   18997      Toledo Edison Co (The)                   Oregon
# 13 3.1.0   5027       Delmarva Power & Light Co                Oregon
# 14 3.1.0   3755       Cleveland Electric Illuminating Co (The) Oregon
# 15 3.1.0   40437      Emerald Peoples Utility District         Oregon
# 16 3.1.0   40437      Emerald Peoples Utility District         Oregon
# 17 3.1.0   40437      Emerald Peoples Utility District         Oregon
# 18 3.1.0   4922       Dayton Power & Light Co (The)            Oregon
# 19 3.1.0   4922       Dayton Power & Light Co (The)            Oregon
# 20 3.1.0   13511      New York State Electric & Gas Corp       Oregon

# %%
electricity.prices %>%
    filter(address=='Hermiston')
# Out:
#   address   commercial industrial residential source                 version
# 1 Hermiston 0.0635     0.0518     0.0739      Ventyx Research (2012) 3.1.0
#   company_id utility_name
# 1 8515|19325 Hermiston OR (City of)|Umatilla Electric Coop

# %% [markdown]
# Write to file

# %%
electricity.prices %>%
    write_csv('data/electricity_price_OR.csv')

# %% [markdown]
# ### Idaho

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Idaho') %>%
    distinct() %>%
    arrange(commercial, industrial, residential) %>%
    head(10)
# Out:
#    address   commercial industrial residential source                 version
# 1  Moreland  0.0276     0.0064     0.082       Ventyx Research (2012) 3.1.0
# 2  Irwin     0.0337     0.0112     0.0746      Ventyx Research (2012) 3.1.0
# 3  Blanchard 0.0337     0.0112     0.0746      Ventyx Research (2012) 3.1.0
# 4  Lake Fork 0.0363     0.0077     0.0906      Ventyx Research (2012) 3.1.0
# 5  Rockland  0.0415     0.0228     0.0694      Ventyx Research (2012) 3.1.0
# 6  Lewiston  0.0415     0.0228     0.0694      Ventyx Research (2012) 3.1.0
# 7  Dayton    0.0483     0.0196     0.1179      Ventyx Research (2012) 3.1.0
# 8  Swanlake  0.0494     0.0208     0.0924      Ventyx Research (2012) 3.1.0
# 9  Weiser    0.0544     0.0484     0.0661      Ventyx Research (2012) 3.1.0
# 10 Burley    0.0576     0.0548     0.0677      Ventyx Research (2012) 3.1.0
#    company_id utility_name                       State
# 1  14715      PPL Electric Utilities Corp        Idaho
# 2  20387      West Penn Power Co                 Idaho
# 3  20387      West Penn Power Co                 Idaho
# 4  NA         AmerenCILCO                        Idaho
# 5  3266       Central Maine Power Co             Idaho
# 6  3266       Central Maine Power Co             Idaho
# 7  4922       Dayton Power & Light Co (The)      Idaho
# 8  13511      New York State Electric & Gas Corp Idaho
# 9  20297      Weiser ID (City of)                Idaho
# 10 2545       Burley ID (City of)                Idaho

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Idaho') %>%
    distinct() %>%
    arrange(industrial, commercial, residential) %>%
    head(10)
# Out:
#    address     commercial industrial residential source                 version
# 1  Moreland    0.0276     0.0064     0.082       Ventyx Research (2012) 3.1.0
# 2  Lake Fork   0.0363     0.0077     0.0906      Ventyx Research (2012) 3.1.0
# 3  Irwin       0.0337     0.0112     0.0746      Ventyx Research (2012) 3.1.0
# 4  Blanchard   0.0337     0.0112     0.0746      Ventyx Research (2012) 3.1.0
# 5  Dayton      0.0483     0.0196     0.1179      Ventyx Research (2012) 3.1.0
# 6  Swanlake    0.0494     0.0208     0.0924      Ventyx Research (2012) 3.1.0
# 7  Rockland    0.0415     0.0228     0.0694      Ventyx Research (2012) 3.1.0
# 8  Lewiston    0.0415     0.0228     0.0694      Ventyx Research (2012) 3.1.0
# 9  Springfield 0.0771     0.0328     0.0977      Ventyx Research (2012) 3.1.0
# 10 Challis     0.068      0.0336     0.0796      Ventyx Research (2012) 3.1.0
#    company_id utility_name                         State
# 1  14715      PPL Electric Utilities Corp          Idaho
# 2  NA         AmerenCILCO                          Idaho
# 3  20387      West Penn Power Co                   Idaho
# 4  20387      West Penn Power Co                   Idaho
# 5  4922       Dayton Power & Light Co (The)        Idaho
# 6  13511      New York State Electric & Gas Corp   Idaho
# 7  3266       Central Maine Power Co               Idaho
# 8  3266       Central Maine Power Co               Idaho
# 9  17828      Springfield Water Light & Power Dept Idaho
# 10 16565      Salmon River Electric Coop Inc       Idaho

# %% [markdown]
# ### Washington

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Washington') %>%
    filter(commercial =='no data') %>%
    nrow()
# Out:
# [1] 421

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Washington') %>%
    distinct() %>%
    inner_join(cities.usa %>% select(zip=`Zip Code`, address=`Place Name`) %>%
                  group_by(address) %>%
                  summarize(zip=min(zip)) %>%
                  ungroup()) %>%
    arrange(commercial, industrial, residential) %>%
    head(20)
# Out:
# Joining, by = "address"
#    address        commercial industrial residential source
# 1  East Wenatchee 0.0193     0.0239     0.0264      Ventyx Research (2012)
# 2  Orondo         0.0193     0.0239     0.0264      Ventyx Research (2012)
# 3  Dupont         0.0276     0.0064     0.082       Ventyx Research (2012)
# 4  Vaughn         0.0276     0.0064     0.082       Ventyx Research (2012)
# 5  Acme           0.0337     0.0112     0.0746      Ventyx Research (2012)
# 6  Everson        0.0337     0.0112     0.0746      Ventyx Research (2012)
# 7  Uniontown      0.0337     0.0112     0.0746      Ventyx Research (2012)
# 8  Wenatchee      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 9  Ardenvoir      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 10 Cashmere       0.0344     0.0218     0.0322      Ventyx Research (2012)
# 11 Chelan Falls   0.0344     0.0218     0.0322      Ventyx Research (2012)
# 12 Entiat         0.0344     0.0218     0.0322      Ventyx Research (2012)
# 13 Peshastin      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 14 Stehekin       0.0344     0.0218     0.0322      Ventyx Research (2012)
# 15 Mount Vernon   0.0363     0.0077     0.0906      Ventyx Research (2012)
# 16 Morton         0.0363     0.0077     0.0906      Ventyx Research (2012)
# 17 Centralia      0.0363     0.0077     0.0906      Ventyx Research (2012)
# 18 Quincy         0.0363     0.0077     0.0906      Ventyx Research (2012)
# 19 Danville       0.0363     0.0077     0.0906      Ventyx Research (2012)
# 20 Beaver         0.0372     0.0135     0.1144      Ventyx Research (2012)
#    version company_id utility_name                State      zip
# 1  3.1.0   5326       PUD No 1 of Douglas County  Washington 98802
# 2  3.1.0   5326       PUD No 1 of Douglas County  Washington 98843
# 3  3.1.0   14715      PPL Electric Utilities Corp Washington 45837
# 4  3.1.0   14715      PPL Electric Utilities Corp Washington 59487
# 5  3.1.0   20387      West Penn Power Co          Washington 15610
# 6  3.1.0   20387      West Penn Power Co          Washington 15631
# 7  3.1.0   20387      West Penn Power Co          Washington 15401
# 8  3.1.0   3413       PUD No 1 of Chelan County   Washington 98801
# 9  3.1.0   3413       PUD No 1 of Chelan County   Washington 98811
# 10 3.1.0   NA         Cashmere Light Dept         Washington 98815
# 11 3.1.0   3413       PUD No 1 of Chelan County   Washington 98817
# 12 3.1.0   3413       PUD No 1 of Chelan County   Washington 98822
# 13 3.1.0   3413       PUD No 1 of Chelan County   Washington 98847
# 14 3.1.0   3413       PUD No 1 of Chelan County   Washington 98852
# 15 3.1.0   NA         AmerenIP                    Washington  4352
# 16 3.1.0   NA         AmerenCILCO                 Washington 14508
# 17 3.1.0   NA         AmerenIP                    Washington 62801
# 18 3.1.0   NA         AmerenCIPS                  Washington  2169
# 19 3.1.0   NA         AmerenIP                    Washington  3819
# 20 3.1.0   5487       Duquesne Light Co           Washington 15009

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Washington') %>%
    distinct() %>%
    arrange(industrial, commercial, residential) %>%
    head(20)
# Out:
#    address      commercial industrial residential source
# 1  Dupont       0.0276     0.0064     0.082       Ventyx Research (2012)
# 2  Vaughn       0.0276     0.0064     0.082       Ventyx Research (2012)
# 3  Mount Vernon 0.0363     0.0077     0.0906      Ventyx Research (2012)
# 4  Morton       0.0363     0.0077     0.0906      Ventyx Research (2012)
# 5  Centralia    0.0363     0.0077     0.0906      Ventyx Research (2012)
# 6  Quincy       0.0363     0.0077     0.0906      Ventyx Research (2012)
# 7  Danville     0.0363     0.0077     0.0906      Ventyx Research (2012)
# 8  Harrington   0.0435     0.0099     0.1365      Ventyx Research (2012)
# 9  Acme         0.0337     0.0112     0.0746      Ventyx Research (2012)
# 10 Everson      0.0337     0.0112     0.0746      Ventyx Research (2012)
#    version company_id utility_name                State
# 1  3.1.0   14715      PPL Electric Utilities Corp Washington
# 2  3.1.0   14715      PPL Electric Utilities Corp Washington
# 3  3.1.0   NA         AmerenIP                    Washington
# 4  3.1.0   NA         AmerenCILCO                 Washington
# 5  3.1.0   NA         AmerenIP                    Washington
# 6  3.1.0   NA         AmerenCIPS                  Washington
# 7  3.1.0   NA         AmerenIP                    Washington
# 8  3.1.0   5027       Delmarva Power & Light Co   Washington
# 9  3.1.0   20387      West Penn Power Co          Washington
# 10 3.1.0   20387      West Penn Power Co          Washington

# %%
electricity.prices %>%
    inner_join(cities.selected, by = c("address"="Place Name")) %>%
    filter(State == 'Washington', startsWith(utility_name, "PUD")) %>%
    distinct() %>%
    arrange(industrial, commercial, residential) %>%
    head(10)
# Out:
#    address        commercial industrial residential source
# 1  Wenatchee      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 2  Ardenvoir      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 3  Chelan Falls   0.0344     0.0218     0.0322      Ventyx Research (2012)
# 4  Entiat         0.0344     0.0218     0.0322      Ventyx Research (2012)
# 5  Peshastin      0.0344     0.0218     0.0322      Ventyx Research (2012)
# 6  Stehekin       0.0344     0.0218     0.0322      Ventyx Research (2012)
# 7  East Wenatchee 0.0193     0.0239     0.0264      Ventyx Research (2012)
# 8  Orondo         0.0193     0.0239     0.0264      Ventyx Research (2012)
# 9  Moses Lake     0.0374     0.0328     0.0485      Ventyx Research (2012)
# 10 Soap Lake      0.0374     0.0328     0.0485      Ventyx Research (2012)
#    version company_id utility_name               State
# 1  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 2  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 3  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 4  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 5  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 6  3.1.0   3413       PUD No 1 of Chelan County  Washington
# 7  3.1.0   5326       PUD No 1 of Douglas County Washington
# 8  3.1.0   5326       PUD No 1 of Douglas County Washington
# 9  3.1.0   14624      PUD No 2 of Grant County   Washington
# 10 3.1.0   14624      PUD No 2 of Grant County   Washington

# %%
cities.usa %>%
    filter(endsWith(`Place Name`, "Wenatchee"))
# Out:
#   Zip Code Place Name     State      State Abbreviation County  Latitude
# 1 98801    Wenatchee      Washington WA                 Chelan  47.4253
# 2 98802    East Wenatchee Washington WA                 Douglas 47.4186
# 3 98807    Wenatchee      Washington WA                 Chelan  47.4235
#   Longitude
# 1 -120.3273
# 2 -120.2731
# 3 -120.3103

# %% [markdown]
# Define a function to calculate distance based on coordinates

# %%
get_distance = function(latFrom, lonFrom, latTo, lonTo) {
    return(sqrt((latTo - latFrom)^2 + (lonTo - lonFrom)^2))
}

# %%
cities.usa %>%
    mutate(distance = get_distance(47.4253, -120.3273, Latitude, Longitude)) %>%
    filter(distance <= 1) %>%
    arrange(distance) %>%
    head(10)
# Out:
#    Zip Code Place Name     State      State Abbreviation County  Latitude
# 1  98801    Wenatchee      Washington WA                 Chelan  47.4253
# 2  98807    Wenatchee      Washington WA                 Chelan  47.4235
# 3  98802    East Wenatchee Washington WA                 Douglas 47.4186
# 4  98836    Monitor        Washington WA                 Chelan  47.4852
# 5  98828    Malaga         Washington WA                 Chelan  47.3553
# 6  98850    Rock Island    Washington WA                 Douglas 47.3706
# 7  98815    Cashmere       Washington WA                 Chelan  47.5173
# 8  98821    Dryden         Washington WA                 Chelan  47.5412
# 9  98822    Entiat         Washington WA                 Chelan  47.7057
# 10 98847    Peshastin      Washington WA                 Chelan  47.5458
#    Longitude distance
# 1  -120.3273 0.00000000
# 2  -120.3103 0.01709503
# 3  -120.2731 0.05461254
# 4  -120.4158 0.10686562
# 5  -120.2086 0.13780308
# 6  -120.1378 0.19723676
# 7  -120.5033 0.19859507
# 8  -120.5609 0.26077149
# 9  -120.2760 0.28505412
# 10 -120.5961 0.29457374
